# %%
using Flux
using Flux.Optimise: update!
using Flux.Losses: mae, mse
using DiffEqFlux
using DiffEqSensitivity
using DifferentialEquations

using ProgressBars
using LinearAlgebra

using Random
using ProgressBars
using DelimitedFiles
using Plots, Colors, Printf, Profile

# %%
# using Distributed
# t = @async addprocs(8)
BLAS.set_num_threads(1)
@show Threads.nthreads();
# Out:
# Threads.nthreads() = 8

# %%
# Problem settings
function robertson(dy, y, p, t)
    k = [0.04, 3e7, 1e4] .* p
    dy[1] = -k[1]*y[1]+k[3]*y[2]*y[3]
    dy[2] =  k[1]*y[1]-k[2]*y[2]^2-k[3]*y[2]*y[3]
    dy[3] =  k[2]*y[2]^2
end

y0 = [1.0, 0.0, 0.0]
datasize = 100
tsteps = 10 .^ range(log10(1e-4), log10(1e8), length=datasize)
tspan = (0.0, tsteps[end]+1e-3)

p_true = [1, 1, 1]
weights = [1, 2e4, 1]

# solver = DifferentialEquations.CVODE_BDF()
solver = KenCarp4();
prob = ODEProblem(robertson, y0, tspan, p_true);
y_true = solve(prob, solver, p=p_true, saveat=tsteps);

# %%
# define the problem
scale = maximum(y_true, dims=2);
function predict_ode(p) # Our 1-layer "neural network"
    sol = solve(prob, solver, p=p, saveat=tsteps)
    pred = Array(sol)
    if sol.retcode == :Success
        nothing
    else
        println("ode solver failed")
    end
    return pred
end
function loss_ode(p; y_train=y_true) 
    return sum(abs2, (predict_ode(p) - y_train) ./ scale);
end

# settings for plots
Plots.pyplot()
Plots.resetfontsizes()
Plots.scalefontsizes(1.5)
function valid(tsteps, y_true, y_pred; line1=(3, :scatter), line2=(2, :solid))
    IJulia.clear_output(true)
    h = plot(legend=false, size=(600,400), framestyle=:box, 
             palette=palette(:tab10, length(weights)))
    plot!(tsteps, (y_true .* weights)', xscale=:log10, line=line1)
    plot!(tsteps, (y_pred .* weights)', xscale=:log10, line=line2)
    return h
end
# Out:
# valid (generic function with 1 method)

# %%
function train(i_exp, p_init, noise_level; n_epoch=300, opt = ADAM(0.1))
    rng = MersenneTwister(0x7777777 * i_exp);
    p_pred = deepcopy(p_init);
    y_pred = predict_ode(p_pred)
    y_noise = y_true + noise_level .* (rand(rng, length(y0), length(tsteps)).-0.5) .* scale;
    
    losses_y = Vector{Float64}()
    history_p = Vector{Array{Float64}}();
    for epoch in 1:n_epoch
        grad = Flux.gradient(x -> loss_ode(x; y_train=y_noise), p_pred)[1]
        update!(opt, p_pred, grad)
        
        loss_y = loss_ode(p_pred; y_train=y_noise)
        push!(losses_y, deepcopy(loss_y))
        push!(history_p, deepcopy(p_pred))
    end
    return losses_y, history_p;
end
# Out:
# train (generic function with 1 method)

# %%
rng = MersenneTwister(0x7777777);
n_exp = 100;
n_epoch = 300;
p_init_arr = exp.(rand(rng, length(p_true), n_exp) .* 2 .- 1);
noise_level_arr = 10 .^ (rand(rng, n_exp) .* 2.5 .- 3); # [10^-3 ~ 10^-0.5] or [(0.1% ~ 30%)]

losses_y_exps = zeros(n_exp, n_epoch);
history_p_exps = zeros(n_exp, n_epoch, length(p_true));

# %%
for i in 1:100
    p_init = p_init_arr[:,i];
    noise_level = noise_level_arr[i];
    
    losses_y, history_p = train(i, p_init, noise_level; n_epoch=300);
    losses_y_exps[i,:] = deepcopy(losses_y);
    history_p_exps[i,:,:] = deepcopy(hcat(history_p...)');
    
    @show i, losses_y[end], history_p[end];
end
# Out:
# (i, losses_y[end], history_p[end]) = (1, 0.009212733731039051, [0.991744122117618, 0.9965322973121291, 0.9899012016541647])
# (i, losses_y[end], history_p[end]) = (2, 0.029782196573143745, [1.002968493337486, 1.001750271580803, 1.0112516326360206])
# (i, losses_y[end], history_p[end]) = (3, 0.0030933582576631227, [1.0032882255363704, 1.0044913781644969, 1.0050771505679277])
# (i, losses_y[end], history_p[end]) = (4, 0.0094711776848136, [1.0045894302406417, 1.0028191073624704, 1.0020046927114088])
# (i, losses_y[end], history_p[end]) = (5, 0.0007712441171335005, [1.0001626921841429, 0.9990983451405098, 0.9995408878841069])
# (i, losses_y[end], history_p[end]) = (6, 0.0019581320932503415, [1.0007599949170383, 1.001588576131838, 1.0010369850555003])
# (i, losses_y[end], history_p[end]) = (7, 4.130863983403938, [1.0969296274136406, 1.1338258429742434, 1.0888279678845008])
# (i, losses_y[end], history_p[end]) = (8, 0.028452447419746518, [1.0117165455468216, 1.0047966543353017, 1.0231815030963656])
# (i, losses_y[end], history_p[end]) = (9, 0.30187435832726806, [1.003274254119614, 1.0052132378217873, 0.9622110434199842])
# (i, losses_y[end], history_p[end]) = (10, 0.5463433114513794, [1.0078971921152744, 0.9954802607720568, 0.9980694024165034])
# (i, losses_y[end], history_p[end]) = (11, 6.938049041038832, [1.0495099081469343, 1.0733856217614994, 1.0174050030632356])
# (i, losses_y[end], history_p[end]) = (12, 0.0042725574004707926, [0.996282852157758, 0.9968261389389357, 0.9959629362922424])
# (i, losses_y[end], history_p[end]) = (13, 1.0728763096237208, [1.0706044281526927, 1.0926535351236593, 1.2277265287898333])
# (i, losses_y[end], history_p[end]) = (14, 0.003129375189516071, [1.000918834668285, 1.0020664057658208, 1.001113868502009])
# (i, losses_y[end], history_p[end]) = (15, 0.026719547658749707, [0.9999514780914309, 0.9983574631994627, 1.0117904930621424])
# (i, losses_y[end], history_p[end]) = (16, 0.010005663686985121, [1.0027443217246526, 1.0025923940219685, 1.0006151988954688])
# (i, losses_y[end], history_p[end]) = (17, 7.596543558096438, [1.0843870124480672, 1.0700287266422046, 0.9512759472775224])
# (i, losses_y[end], history_p[end]) = (18, 0.4812369336536995, [1.0575158407297922, 1.0601262831368292, 1.1233911639732832])
# (i, losses_y[end], history_p[end]) = (19, 0.00044839637715752623, [0.9984948465638717, 0.9987885084992786, 0.9964663408129305])
# (i, losses_y[end], history_p[end]) = (20, 9.872898256208952e-5, [1.0004987402704089, 1.0000867476539248, 1.0003182308642242])
# (i, losses_y[end], history_p[end]) = (21, 0.10115113043216632, [1.0022082538347317, 1.0109872694532696, 1.002884009342759])
# (i, losses_y[end], history_p[end]) = (22, 1.9266004473539853, [0.9509686197206856, 0.9315797787776045, 0.9472328337080798])
# (i, losses_y[end], history_p[end]) = (23, 1.56707537714696, [0.9660410044816895, 0.9493363740467616, 0.9646665423311371])
# (i, losses_y[end], history_p[end]) = (24, 0.11696718981953046, [1.0292209952799773, 1.0243084135591884, 1.0412665670024133])
# (i, losses_y[end], history_p[end]) = (25, 0.00024176062002298577, [1.0010550000589034, 1.0011905898210678, 1.0024983202784803])
# (i, losses_y[end], history_p[end]) = (26, 1.6530438982214273, [0.909374393765254, 0.9079829792039565, 0.9286744111950074])
# (i, losses_y[end], history_p[end]) = (27, 2.1355922245168046, [1.0217501047894297, 0.9908087057403464, 0.9646609372086166])
# (i, losses_y[end], history_p[end]) = (28, 0.0199337879100481, [1.0105006636775424, 1.0017876634186897, 1.014971774915253])
# (i, losses_y[end], history_p[end]) = (29, 0.024003169713406748, [1.0042811833745453, 1.0017348067953327, 0.999573561680768])
# (i, losses_y[end], history_p[end]) = (30, 0.0068921785992277895, [1.0058137543519106, 1.0054367337967118, 1.004556422095095])
# (i, losses_y[end], history_p[end]) = (31, 4.696708727317908, [0.9439713785208503, 1.1132575666998763, 1.0187709982685031])
# (i, losses_y[end], history_p[end]) = (32, 0.0009843700029886183, [0.9999043704975346, 0.9994590472655844, 1.0000274746859237])
# (i, losses_y[end], history_p[end]) = (33, 0.3745422777772805, [0.9934010063308996, 0.9801817753422214, 0.9455020790756727])
# (i, losses_y[end], history_p[end]) = (34, 0.2752772858026016, [0.9930335404451854, 0.9903904682841675, 1.0408342558518573])
# (i, losses_y[end], history_p[end]) = (35, 0.0009299591738010534, [1.0013332459759834, 1.0010852175346956, 1.0030455397081905])
# (i, losses_y[end], history_p[end]) = (36, 2.3003033842836382, [1.0367280611579777, 1.0198476782368928, 1.1166371231841488])
# (i, losses_y[end], history_p[end]) = (37, 0.0001405000689487902, [1.0006512310119304, 1.0006062606420072, 1.0016309223157625])
# (i, losses_y[end], history_p[end]) = (38, 1.9597932751970337, [0.9003246040787289, 0.9220968295290051, 0.8762300224662184])
# (i, losses_y[end], history_p[end]) = (39, 0.0002172124546358474, [0.9999937122081506, 0.9999876048665837, 1.0000043400569432])
# (i, losses_y[end], history_p[end]) = (40, 0.22433828198761835, [1.021469290383484, 1.0090287890331946, 1.0251927147188367])
# (i, losses_y[end], history_p[end]) = (41, 0.8132685750057527, [0.967225557938811, 1.0044435947987764, 0.990426026627131])
# (i, losses_y[end], history_p[end]) = (42, 0.00462115201262415, [1.0049173393044522, 1.0063978338644783, 1.0053480589794388])
# (i, losses_y[end], history_p[end]) = (43, 4.6229161400438095, [0.8942198800261972, 0.8512784828562224, 0.8744261990827074])
# (i, losses_y[end], history_p[end]) = (44, 0.0006925416946401834, [1.0013930526165011, 1.0013156498303306, 1.0031620762259588])
# (i, losses_y[end], history_p[end]) = (45, 2.9553396952792244, [1.0028530161254061, 0.9619375581083087, 0.8747463827456462])
# (i, losses_y[end], history_p[end]) = (46, 0.00026672785632897775, [1.0003612421774606, 0.999991110090627, 1.0004454851538596])
# (i, losses_y[end], history_p[end]) = (47, 0.07612087510984338, [1.0139225877204532, 1.0100267927770687, 1.024063746012919])
# (i, losses_y[end], history_p[end]) = (48, 1.0840751500791834, [0.982670011540418, 1.00362474366323, 0.9753650187327215])
# (i, losses_y[end], history_p[end]) = (49, 0.001604106710303114, [0.9997948366663235, 0.9989450323326237, 0.998741108813078])
# (i, losses_y[end], history_p[end]) = (50, 0.0016109089985148965, [0.9971128386927653, 0.9961713935771316, 0.9957218215722092])
# (i, losses_y[end], history_p[end]) = (51, 0.013787201918810582, [1.0001405723553647, 1.0016190480728848, 0.9987066903645168])
# (i, losses_y[end], history_p[end]) = (52, 4.825705768493086, [0.9688592106764812, 1.0308433804492023, 0.8811482897072486])
# (i, losses_y[end], history_p[end]) = (53, 0.00010616079598319024, [1.0003515199259974, 1.0001864024278377, 1.0010754730932638])
# (i, losses_y[end], history_p[end]) = (54, 0.3339506737643797, [0.9758154747461477, 0.9883619696099655, 0.9378983508377622])
# (i, losses_y[end], history_p[end]) = (55, 0.2488494211096785, [0.9714427018884692, 0.9791595700394389, 0.9525842120947026])
# (i, losses_y[end], history_p[end]) = (56, 0.00016963035528730442, [1.0000221734180157, 1.000000609542493, 1.000849602297454])
# (i, losses_y[end], history_p[end]) = (57, 0.0001844845709359441, [0.998889177362031, 0.9988695936626961, 0.998449421455717])
# (i, losses_y[end], history_p[end]) = (58, 0.012241120338620112, [1.0053574653671336, 1.004478526676619, 1.0114927060015853])
# (i, losses_y[end], history_p[end]) = (59, 0.2655149516433894, [0.9570191611889096, 0.9773876138796534, 0.9165997030676752])
# (i, losses_y[end], history_p[end]) = (60, 0.0005982072021800647, [0.9984307884776796, 0.9997981939373217, 0.9980971985566146])
# (i, losses_y[end], history_p[end]) = (61, 0.00010888700698230365, [1.000682497684672, 1.0001819833823706, 1.000670479326657])
# (i, losses_y[end], history_p[end]) = (62, 2.5116907964452833, [1.1149419497185042, 1.1170205356921177, 1.2589717353195315])
# (i, losses_y[end], history_p[end]) = (63, 3.1496851520651417, [1.115986420761073, 1.2188554865220995, 1.0718416998401978])
# (i, losses_y[end], history_p[end]) = (64, 5.307291128869659, [0.9756355702863055, 0.9858418921720938, 0.951523803700987])
# (i, losses_y[end], history_p[end]) = (65, 5.610714478181316, [1.074237698899271, 1.0434746893227536, 1.0410297617170372])
# (i, losses_y[end], history_p[end]) = (66, 1.9822833575052576, [0.9797539487336983, 0.9780370306838194, 1.0095834668812034])
# (i, losses_y[end], history_p[end]) = (67, 6.303667649915162, [0.9118017522062125, 0.9500967187471585, 0.7628668034014805])
# (i, losses_y[end], history_p[end]) = (68, 0.10225872578829173, [0.9800960901317674, 0.9857293799080024, 0.9856330950187572])
# ┌ Warning: dt <= dtmin. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase /home/suxy15/.julia/packages/SciMLBase/070vZ/src/integrator_interface.jl:345
# (i, losses_y[end], history_p[end]) = (69, 0.9618190817125908, [0.9950727177448491, 1.007549907665925, 1.01471843289429])
# (i, losses_y[end], history_p[end]) = (70, 0.01576875945203544, [1.0043523183650729, 1.009517454558358, 1.0111986443713663])
# (i, losses_y[end], history_p[end]) = (71, 0.021021309226712945, [1.0124109839684388, 1.0112381279124032, 1.0116235539201281])
# ┌ Warning: dt <= dtmin. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase /home/suxy15/.julia/packages/SciMLBase/070vZ/src/integrator_interface.jl:345
# (i, losses_y[end], history_p[end]) = (72, 2.8776558777855152, [1.044760036162613, 1.0437593812122568, 1.090293492251057])
# (i, losses_y[end], history_p[end]) = (73, 0.01981050825970746, [0.99184679728859, 0.9906685607633228, 0.9857416827496768])
# (i, losses_y[end], history_p[end]) = (74, 0.05574597100314495, [1.0005135716739073, 0.9970038260633277, 0.9877433824301515])
# (i, losses_y[end], history_p[end]) = (75, 0.07682970252839467, [0.9872756626819429, 0.9869786037491777, 0.9761852148361521])
# (i, losses_y[end], history_p[end]) = (76, 0.029509522919404202, [1.0172950004384531, 1.0192299906930868, 1.0190938532785414])
# (i, losses_y[end], history_p[end]) = (77, 0.12507964541053815, [0.9931248129848118, 0.9777965697277209, 0.9910900048005435])
# (i, losses_y[end], history_p[end]) = (78, 9.8166620351877, [1.1791576466522107, 1.0890686940823766, 1.1520602033468508])
# (i, losses_y[end], history_p[end]) = (79, 0.007100956333552476, [1.0026392868195557, 1.001680812937779, 1.0003365547481613])
# (i, losses_y[end], history_p[end]) = (80, 0.02369856444206465, [0.9964633537108414, 0.998677390910135, 0.9899325825510462])
# (i, losses_y[end], history_p[end]) = (81, 0.10760488956915704, [0.9866238304455289, 0.9877580198848656, 1.0087833320664223])
# (i, losses_y[end], history_p[end]) = (82, 0.592857881525632, [1.042707574457922, 1.0177614293541006, 1.032932128212364])
# (i, losses_y[end], history_p[end]) = (83, 0.3272909510980229, [1.0575693602088478, 1.019587003106447, 1.0896783165773045])
# (i, losses_y[end], history_p[end]) = (84, 0.31478478023303547, [0.9887800323955674, 0.9989870704241305, 0.9632571799977201])
# (i, losses_y[end], history_p[end]) = (85, 0.00046018453027710677, [0.999402636939447, 0.9998631059608073, 0.9987343701837638])
# (i, losses_y[end], history_p[end]) = (86, 0.36132156861383163, [1.022015430914942, 1.0387380038044705, 1.0183839610643723])
# (i, losses_y[end], history_p[end]) = (87, 4.864944906326565, [0.8465789546774607, 0.8814755906865984, 0.8093938897662604])
# (i, losses_y[end], history_p[end]) = (88, 0.0006025420402850697, [1.000483273879772, 0.9999284892350578, 1.0002155363035838])
# (i, losses_y[end], history_p[end]) = (89, 4.514790939678774, [0.9856823749959396, 0.9976876318765624, 0.9268096278242106])
# (i, losses_y[end], history_p[end]) = (90, 0.3608129967776061, [0.9978580307180458, 1.0239980111724267, 1.0115791657570878])
# ┌ Warning: dt <= dtmin. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase /home/suxy15/.julia/packages/SciMLBase/070vZ/src/integrator_interface.jl:345
# (i, losses_y[end], history_p[end]) = (91, 1.9087861775526507, [0.9558280896019178, 0.9658934002319332, 1.0182287317081975])
# (i, losses_y[end], history_p[end]) = (92, 0.004829318528690246, [1.0033331612820224, 1.0035452141250452, 1.0067069162077458])
# (i, losses_y[end], history_p[end]) = (93, 4.753502729975887, [1.2142790185876362, 1.084442749664451, 1.4383702649726073])
# (i, losses_y[end], history_p[end]) = (94, 2.393486545236715, [1.05086387633363, 1.0310144449631975, 0.9353834928799326])
# (i, losses_y[end], history_p[end]) = (95, 0.0669284207970772, [0.9966916768502797, 1.0005966084822924, 1.001327732944686])
# (i, losses_y[end], history_p[end]) = (96, 0.0026508294686083123, [0.9974420482503642, 0.9996332731280553, 0.9967859423369183])
# (i, losses_y[end], history_p[end]) = (97, 8.65608881791852, [0.9073720632139051, 0.976606053557888, 1.0873043448345254])
# (i, losses_y[end], history_p[end]) = (98, 0.8458185706905214, [1.05728534824838, 1.033957062850964, 1.1080155665064033])
# (i, losses_y[end], history_p[end]) = (99, 6.193082641787622, [0.9939252182277861, 0.9256980428627659, 0.9738365880936617])
# (i, losses_y[end], history_p[end]) = (100, 0.0774450491412892, [0.9838132482800636, 0.9953000215009145, 0.9830969458536865])

# %%
# h = plot(legend=false)
# for i in 1:10
#     plot!(tsteps, (y_init .* weights)', xscale=:log10, color = "#BBBBBB", alpha=0.3)
#     # plot!(tsteps, (y_pred .* weights)', xscale=:log10, color = "#BB0000", alpha=0.3)
# end
# plot!(tsteps, (y_true .* weights)', xscale=:log10)
# display(h)

# %%
n_solved = 100;
losses_p_exps = zeros(n_exp, n_epoch);
errors_p_exps = zeros(n_exp, n_epoch);
for i=1:n_solved
    losses_p_exps[i,:] = sum(abs2.(history_p_exps[i,:,:] .- 1), dims=2)
    errors_p_exps[i,:] = sum(abs.(history_p_exps[i,:,:] .- 1), dims=2)./3
end

h1 = plot(xlabel="Noise", ylabel="Final y loss", size=(400,300), legend=false);
plot!(noise_level_arr[1:n_solved], (losses_y_exps[1:n_solved, end] ./ datasize ./ 3) .^ 0.5,  xscale=:log10, yscale=:log10, line=(3, :scatter), color=:black)

h2 = plot(xlabel="Noise", ylabel="Final p loss", size=(400,300), legend=false);
plot!(noise_level_arr[1:n_solved], (losses_p_exps[1:n_solved, end] ./ 3) .^ 0.5,  xscale=:log10, yscale=:log10, line=(3, :scatter), color=:black)

h = plot(h1, h2, layout=(2,1), size=(400,400), framestyle=:box)

# %%
h1 = plot(xlabel="Epochs", ylabel="y loss", size=(400,300), legend=false);
for i=1:n_solved
    if noise_level_arr[i] < 3e-1 && noise_level_arr[i] > 1e-3
        a = sqrt(noise_level_arr[i] / 10^-0.5)
        plot!(1:n_epoch, (losses_y_exps[i, :] ./ datasize ./ 3) .^ 0.5, yscale=:log10, line=(1, :solid), alpha=a, color=:black)
    end
end

h2 = plot(xlabel="Epochs", ylabel="p loss", size=(400,300), legend=false);
for i=1:n_solved
    if noise_level_arr[i] < 3e-1 && noise_level_arr[i] > 1e-3
        a = sqrt(noise_level_arr[i] / 10^-0.5)
        plot!(1:n_epoch, (losses_p_exps[i, :] ./ 3) .^ 0.5, yscale=:log10, line=(1, :solid), alpha=a, color=:black)
    end
end
h = plot(h1, h2, layout=(2,1), size=(400,400), framestyle=:box)

# %%
# i=1;
# p_pred = p_init_arr[:,i];
# ps = Flux.params(p_pred)
# function loss()
#     return sum(abs2, (predict_ode(p_pred) - y_true) ./ scale);
# end
# opt = ADAM(0.1)
# data = Iterators.repeated((), 300);
# @time Flux.train!(loss, ps, data, opt);
# # about 67 secs; manualy 80 secs

# %%
# single case 1: without noise
i = 1;
p_init = p_init_arr[:,i];
noise_level = 0.;

n0_losses_y, n0_history_p = train(i, p_init, noise_level; n_epoch=300);
# Out:
# 3-element Array{Float64,1}:
#  0.9999844951971135
#  0.9999735980158198
#  0.9999863123762277

# %%
p_init = p_init_arr[:,i];
noise_level = 0.;

rng = MersenneTwister(0x7777777 * i);
y_noise = y_true + noise_level .* (rand(rng, length(y0), length(tsteps)).-0.5) .* scale;
p_pred = n0_history_p[end]

y_init = predict_ode(p_init)
display(valid(tsteps, y_noise, y_init))
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %%
y_pred = predict_ode(p_pred)
valid(tsteps, y_noise, y_pred)

# %%
# single case 2: 30% noise
i = 1
p_init = p_init_arr[:,i];
noise_level = 0.1;

n3_losses_y, n3_history_p = train(i, p_init, noise_level; n_epoch=300);
# Out:
# 3-element Array{Float64,1}:
#  0.9999844951971135
#  0.9999735980158198
#  0.9999863123762277

# %%
i=50
p_init = p_init_arr[:,i];
noise_level = 0.3;

rng = MersenneTwister(0x7777777 * i);
y_noise = y_true + noise_level .* (rand(rng, length(y0), length(tsteps)).-0.5) .* scale;
p_pred = n3_history_p[end]

y_init = predict_ode(p_init)
valid(tsteps, y_noise, y_init)

# %%
y_pred = predict_ode(p_pred)
valid(tsteps, y_noise, y_pred)
